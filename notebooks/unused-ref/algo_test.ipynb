# %%
import numpy as np
from numpy import (
    arctan2,
    float16,
    hypot,
    sinc,
    tan,
    arctan,
    sqrt,
    power,
    cos,
    cosh,
    sin,
    pi,
    log,
    exp,
    log10,
    log2,
    tanh,
    arctanh,
    arcsin,
    sinh,
    square,
    exp2,
)

# item0 = [1.46, 5.92, 1.52]
# item1 = [0.56, 5.92, 1.12]
# ----------------------------
# item0 = [-1.4, -4.72, 1.24]
# item1 = [-2.36, -4.72, 1.16]
# ----------------------------
item0 = [-2.6, -7.28, 1.72]
item1 = [-0.84, -7.28, 1.72]
item2 = [0.76, -5.88, 0.52]
item3 = [2.88, 5.88, 1.0]


# def not_sobel():
#     global item1
#     global item2
#     global item3

#     sp1 = pow(sum(item1[0]), 2)
#     sp11 = pow(sum(item1[1]), 2)
#     sp2 = pow(sum(item2), 2)
#     sp3 = pow(sum(item3), 2)
#     print("1: ", sp1)
#     print("11: ", sp11)
#     print("2: ", sp2)
#     print("3: ", sp3)
#     print("-----------------------")
#     print("1=self")
#     spa = abs(atan(sp1) + 1)
#     print(spa * 1.57)
#     print("1v1")
#     print(sqrt(hypot(tan(sp1) * tan(sp11)) / spa))
#     print("1v2")
#     print(sqrt(hypot(tan(sp1) * tan(sp2)) / spa))
#     print("1v3")
#     print(sqrt(hypot(tan(sp1) * tan(sp3)) / spa))
#     print("=========================")


def check_point(ref_point: list, n_point: list):
    ref_cord = square(sum(ref_point))
    n_cord = square(sum(n_point))
    ref_arc = arctan(ref_cord)
    out = sqrt((square(tan(ref_cord) * tan(n_cord))))
    coor = (out / ref_arc) - 1
    print("coor :", coor)
    if coor < 1 and coor > 0:
        print("true")

    # print(out)


if __name__ == "__main__":
    # print("block 1")
    # not_sobel()
    # print("block 2")
    # item1 = [[-1.4, -4.72, 1.24], [-2.36, -4.72, 1.16]]
    # not_sobel()
    # -----------------------
    check_point(item0, item1)
    check_point(item0, item2)
    check_point(item0, item3)
# Out:
# coor : -0.9459045278423094
# coor : -0.5053891552689209
# coor : -0.28171655704330667
